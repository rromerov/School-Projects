# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-RobertoRomeroVielma-A00822314/blob/main/Semana_3_Python_for_Data_Science_(IBM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nombre del alumno:** Roberto Romero Vielma
#
# **Matrícula:** A00822314

# %% [markdown]
# # Numpy 1D Arrays

# %% [markdown]
# Una lista en python es un contenedor que nos permite almacenar y acceder a datos

# %%
a=["0",1,"two","3",4]

# %% [markdown]
# Cada elemento tiene un índice (los voy a representar todos dentro de un ciclo for).

# %%
for i in range(len(a)):
  print("a[",i,"]:",a[i])
# Out:
# a[ 0 ]: 0
# a[ 1 ]: 1
# a[ 2 ]: two
# a[ 3 ]: 3
# a[ 4 ]: 4

# %% [markdown]
# Un arreglo de numpy es similar a una lista, por lo general tiene un tamaño fijo y cada elemento es del mismo tipo.
#
# Para usar numpy debemos importarlo, generalmente con el alias np
#
# La función np.array hará que nuestra lista se convierta en un arreglo numpy

# %%
import numpy as np
a=np.array([0,1,2,3,4])

# %% [markdown]
# Se puede acceder de la misma manera que una lista

# %%
for i in range(len(a)):
  print("a[",i,"]:",a[i])
# Out:
# a[ 0 ]: 0
# a[ 1 ]: 1
# a[ 2 ]: 2
# a[ 3 ]: 3
# a[ 4 ]: 4

# %% [markdown]
# Si usamos la función type, con la variable a podremos ver lo siguiente:

# %%
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# Nos arroja que la variable es de tipo numpy.ndarray.
#
# Si usamos el método dtype podremos darnos cuenta que el tipo de la variable **a** es del tipo entero de 64 bits

# %%
a.dtype
# Out:
# dtype('int64')

# %% [markdown]
# El atributo **size** nos da el número de elementos dentro del array

# %%
a.size #como son 5 elementos el resultado es 5
# Out:
# 5

# %% [markdown]
# El atributo **ndim** nos dirá las dimensionas de nuestro array, en este caso es de 1 una dimensión

# %%
a.ndim
# Out:
# 1

# %% [markdown]
# **Shape** nos devuelve una tupla con valores enteros que nos dice el tamaño del array en cada dimensión

# %% [markdown]
# Podemos crear un arreglo de numpy con números reales, de la siguiente forma:

# %%
b=np.array([3.1,11.02,6.2,213.2,5.2])

# %% [markdown]
# Para verificar que tipo de dato es usamos type()

# %%
type(b)
# Out:
# numpy.ndarray

# %% [markdown]
# Si usamos dtype podremos ver que el array es de tipo "float64", ya que los elementos no son enteros

# %%
b.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Indexing and Slicing
# Podemos cambiar un valor dentro del array de la siguiente manera:

# %%
c=np.array([20,1,2,3,4])
c
# Out:
# array([20,  1,  2,  3,  4])

# %% [markdown]
# Nos interesa cambiar el primer valor, dicho de otra manera la posición 0

# %%
c[0]=100

# %% [markdown]
# Mostramos nuevamente el array:

# %%
c
# Out:
# array([100,   1,   2,   3,   4])

# %% [markdown]
# Ahora cambiamos el último elemento:

# %%
c[-1]=0
c
# Out:
# array([100,   1,   2,   3,   0])

# %% [markdown]
# Como las listas y tuplas podemos recortar un arreglo numpy

# %%
np.array([100,1,2,0])
# Out:
# array([100,   1,   2,   0])

# %% [markdown]
# Podemos seleccionar los elementos en la posición 1 a la 3 de la siguiente manera, no solo eso sino que además los podemos guardar dentro de una nueva variable:

# %%
d=c[1:4]

# %% [markdown]
# Como la listas no se cuentan el último elemento correspodiente al último indice

# %% [markdown]
# Se puden agregar nuevos valores al array de la siguiente manera:

# %%
c[3:5]=300,400
c
# Out:
# array([100,   1,   2, 300, 400])

# %% [markdown]
# ## Operaciones básicas
# Las operaciones realizadas en numpy gastan menos recursos computacionales en comparación a usar las funciones por defecto de Python

# %% [markdown]
# ### Adición de vectores y sustracción

# %% [markdown]
# ![matrices.PNG](data:image/png;base64,...)

# %% [markdown]
# Podemos crear un nuevo vector **z** que sea la suma de **u** más **v** ejemplificado de la siguiente manera:
#
# *z* = *u* + *v*
#
# De tal manera que obteneos el siguiente vector resultante:

# %% [markdown]
# ![Captura23.PNG](data:image/png;base64,...)

# %% [markdown]
# Este vector z es una combinación lineal del vector **u** y el vector **v**

# %% [markdown]
# El siguiente código añadirá las 2 listas y colocará el resultado en la lista **z**.
#
# **Nota:**
# La función zip() puede tomar cualquier iterable como argumento. Se utiliza para devolver un objeto zip que también es un iterador. El iterador devuelto se devuelve como una tupla como una lista, un diccionario o un conjunto.

# %%
u=[1,0]
v=[1,0]
z=[]
for n,m in zip(u,v):
  z.append(n+m)
z
# Out:
# [2, 0]

# %% [markdown]
# Se puede representar en Numpy de la siguiente manera:

# %%
u=np.array([1,0])
v=np.array([0,1])
z=u+v #sumamos los dos vectores
z
# Out:
# array([1, 1])

# %% [markdown]
# Tambíen podemos hacer sustracción con Numpy

# %%
z=u-v
z
# Out:
# array([ 1, -1])

# %% [markdown]
# **Modelo análogo con Python únicamente**

# %%
u=[1,0]
v=[0,1]
z=[]
for n,m in zip (u,v):
  z.append(n-m)
z
# Out:
# [1, -1]

# %% [markdown]
# ## Multiplicación de vector con un escalar
#
# El vector **y** cuenta con 2 filas y 1 columna, el vector **z** es el doble de **y** que se puede representar de la siguiente manera:
#
# ![ejemplo.PNG](data:image/png;base64,...)

# %% [markdown]
# Al efectuarse la multipliación **z** queda de la siguiente manera:
# ![ejemplo2.PNG](data:image/png;base64,...)

# %% [markdown]
# **Representación con Numpy**

# %%
y=np.array([1,2])

z=2*y
z
# Out:
# array([2, 4])

# %% [markdown]
# **Representación sin Numpy**

# %%
y=[1,2]
z=[]

for n in y:
  z.append(2*n)
z
# Out:
# [2, 4]

# %% [markdown]
# ## Producto de 2 arrays Numpy
# El primer componente de **Z** es el producto del primer elemento de **u** y **v**. Para el segundo componente de **Z** es el producto producto del segundo elemento de **u** y **v**.
# ![ejemplo3.PNG](data:image/png;base64,...)

# %% [markdown]
# **Código usando Numpy**

# %%
u=np.array([1,2])
v=np.array([3,2])
z=u*v
z
# Out:
# array([3, 4])

# %% [markdown]
# **Código usando solamente Python**

# %%
u=[1,2]
v=[3,2]
z=[]

for n,m in zip(u,v):
  z.append(n*m)
z
# Out:
# [3, 4]

# %% [markdown]
# ## Producto punto
#
# Es cuando multiplicamos dos vectores y nuestro resultado es un escalar (un número).
#
# ![ejemplo4.PNG](data:image/png;base64,...)

# %% [markdown]
# **Código usando Numpy**

# %%
u=np.array([1,2])
v=np.array([3,1])
result=np.dot(u,v)
result
# Out:
# 5

# %% [markdown]
# ## Añadir una constante a un arreglo Numpy
# Si agregamos un valor escalar a un array, Numpy agregará ese valor a cada elemento.

# %%
u=np.array([1,2,3,-1])
z=u+1
z
# Out:
# array([2, 3, 4, 0])

# %% [markdown]
# ## Funciones universales
# Son funciones que opera en ndarrays

# %% [markdown]
# **Mean** saca el promedio dentro del array

# %%
a=np.array([1,-1,1,-1])
mean_a=a.mean()
mean_a
# Out:
# 0.0

# %% [markdown]
# **Max** Obtiene el número mayor dentro del array

# %%
b=np.array([1,-2,3,4,5])
max_b=b.max()
max_b
# Out:
# 5

# %% [markdown]
# Podemos usar numpy para crear funciones que mapeen arrays de numpy a nuevos arrays de numpy
#
# **Np.pi** nos deja usar el valor de pi

# %%
x=np.array([0,np.pi/2,np.pi])
x
# Out:
# array([0.        , 1.57079633, 3.14159265])

# %% [markdown]
# **Np.sin** aplica la función seno a lo que este dentro de los paréntesis

# %%
y=np.sin(x)
y
# Out:
# array([0.0000000e+00, 1.0000000e+00, 1.2246468e-16])

# %% [markdown]
# La función **np.linspace** devuelve
# números uniformemente espaciados en un intervalo especificado.

# %%
np.linspace(-2,2,num=5)
# Out:
# array([-2., -1.,  0.,  1.,  2.])

# %% [markdown]
# -2 será el punto de inicio, 2 el fin y el num la cantidad de elementos. Si cambiamos la cantidad de muestras a 9 obtenemos lo siguiente:

# %%
np.linspace(-2,2,num=9)
# Out:
# array([-2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ])

# %% [markdown]
# ## Graficando funciones matemáticas

# %%
x=np.linspace(0,2*np.pi,100) # de 0 al doble de pi, con una muestra de 100 elementos
y=np.sin(x)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Arrays dimensionales en Numpy

# %%
a=[[11,12,13],[21,22,23],[31,32,33]]

# %% [markdown]
# Podemos pasar esta lista a un arreglo Numpy de la siguiente manera:

# %%
A=np.array(a)

# %% [markdown]
# Podemos visualizar el array de esta forma:
#
# ![ejemplo5.PNG](data:image/png;base64,...)

# %% [markdown]
# El método **ndim** regresa las dimensiones del array

# %%
A.ndim
# Out:
# 2

# %% [markdown]
# El método **shape** regresa el número de filas y columnas dentro de una tupla

# %%
A.shape
# Out:
# (3, 3)

# %% [markdown]
# El método **size** muestra el tamaño del array

# %%
A.size
# Out:
# 9

# %% [markdown]
# Podemos utilizar paréntesis rectangulares para acceder a los diferentes elementos del array.

# %% [markdown]
# ![ejemplo6.PNG](data:image/png;base64,...)

# %% [markdown]
# A [0] [0] indica el primer elemento de la primer fila
#
# A [1] [1] indica el segundo elemento de la segunda fila
#
# A [2] [1] indica el segundo element de la tercer fila

# %% [markdown]
# También se puede usar el slicing en arrays de Numpy

# %%
A[0,0:2] #regresa la primer fila con las primeras 2 columnas
# Out:
# array([11, 12])

# %%
A[0:2,2] #regresa desde la primer fila hasta la segunda y la última columna
# Out:
# array([13, 23])

# %% [markdown]
# Podemos sumar matrices de la siguiente manera:

# %% [markdown]
# ![ejemplo7.PNG](data:image/png;base64,...)

# %% [markdown]
# Con Numpy se hace de la siguiente manera:

# %%
x=np.array([[1,0],[0,1]])
y=np.array([[2,1],[1,2]])
z=x+y
z
# Out:
# array([[3, 1],
#        [1, 3]])

# %% [markdown]
# Multiplicar un array Numpy a un escalar es idéntico a multiplicar una matriz por un escalar

# %%
y=np.array([[2,1],[1,2]])
z=2*y
z
# Out:
# array([[4, 2],
#        [2, 4]])

# %% [markdown]
# Para el producto punto ambas matrices deben de ser del mismo tamaño, el resultado es un array del mismo tamaño que los originales

# %%
x=np.array([[1,0],[0,1]])
y=np.array([[2,1],[1,2]])
z=x*y
z
# Out:
# array([[2, 0],
#        [0, 2]])

# %% [markdown]
# La multiplicación de las matrices puede ser de difentes tamaños, por ejemplo podemos tener una matriz de 2 x 3 que multiplique a una de 3 x 2
#
# ![ejemplo8.PNG](data:image/png;base64,...)

# %% [markdown]
# Código en python

# %%
A=np.array([[0,1,1],[1,0,1]])
B=np.array([[1,1],[1,1],[-1,1]])
C=np.dot(A,B)
C
# Out:
# array([[0, 2],
#        [0, 2]])

# %% [markdown]
# # APIs Sencillas
# **¿Qué es una API?**
#
# Las API son mecanismos que permiten a dos componentes de software comunicarse entre sí mediante un conjunto de definiciones y protocolos. Por ejemplo, el sistema de software del instituto de meteorología contiene datos meteorológicos diarios. La aplicación meteorológica de su teléfono “habla” con este sistema a través de las API y le muestra las actualizaciones meteorológicas diarias en su teléfono.

# %% [markdown]
# Pandas es un ejemplo de API

# %%
import pandas as pd

# %% [markdown]
# Por ejemplo cuando creamos un diccionario, y lo transformamos en un dataframe hacemos uso de la API de Pandas

# %%
dict_={"a":[11,21,31],"b":[12,22,32]}
df=pd.DataFrame(dict_) #los datos en el diccionario pasan a la API de Pandas

# %%
df.head() #estamos haciendo uso de la API
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
df.mean() #igual aquí
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# ## REST APIs
# Una API REST es una API que se ajusta a los principios de diseño de REST, un estilo de arquitectura también denominado transferencia de estado representacional. Por este motivo, las API REST son a veces denominadas API RESTful.

# %% [markdown]
# ![R6qFq3n.png](data:image/png;base64,...)

# %% [markdown]
# Las API REST se comunican a través de solicitudes HTTP para realizar funciones estándar de base de datos, como crear, leer, actualizar y suprimir registros (también conocidos como CRUD) dentro de un recurso. Por ejemplo, una API REST utilizará una solicitud GET para recuperar un registro, una solicitud POST para crearlo, una solicitud PUT para actualizarlo y una solicitud DELETE para suprimirlo. Todos los métodos HTTP se pueden utilizar en llamadas API. Una API REST bien diseñada es similar a un sitio web que se ejecuta en un navegador web con funcionalidad HTTP incorporada.
#
# El estado de un recurso en un instante específico, o en una indicación de fecha y hora, se conoce como la representación de recursos. Esta información se puede entregar a un cliente en prácticamente cualquier formato, entre ellos JavaScript Object Notation (JSON), HTML, XLT, Python, PHP o un texto sin formato. JSON es popular debido a que es legible tanto por los seres humanos como por las máquinas y debido a que es independiente de un lenguaje de programación.
#
# Las cabeceras y parámetros de solicitud también son importantes en las llamadas de API REST, puesto que incluyen información de identificador importante, como metadatos, autorizaciones, identificadores de recursos uniformes (URI), almacenamiento en memoria caché, cookies y más. Las cabeceras de solicitud y las cabeceras de respuesta, junto con los códigos de estado HTTP convencionales, se utilizan en las API REST bien diseñadas.

# %% [markdown]
# Hacemos un ejemplo de una API

# %% [markdown]
# Usamos pip install para poder acceder a la api

# %%
# !pip install nba_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 2.1 MB/s
# ...
#   Created wheel for nba-api: filename=nba_api-1.1.11-py3-none-any.whl size=251504 sha256=2d8c5848fbffb8b1e11b4bd3ce4617b4fab856fa3a83e4434e853e14f0534ece
#   Stored in directory: /root/.cache/pip/wheels/e3/f4/46/996128675381abc175e306642bae575d372dcf7efc4683e551
# Successfully built nba-api
# ...

# %%
from nba_api.stats.static import teams
nba_teams=teams.get_teams()
nba_teams[:5]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966}]

# %% [markdown]
# Creamos una función llamada one dict para crear un diccionario

# %%
def one_dict(list_dict):
  keys=list_dict[0].keys()
  out_dict={key:[] for key in keys}
  for dict_ in list_dict:
    for key, value in dict_.items():
      out_dict[key].append(value)
  return out_dict

# %% [markdown]
# Usamos la función para transformar los datos de la API en un dataframe

# %%
dict_nba_team=one_dict(nba_teams)

# %%
df_teams=pd.DataFrame(dict_nba_team)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %% [markdown]
# Hacemos un subset para encontrar la información que queremos

# %%
df_warriors=df_teams[df_teams["nickname"]=="Warriors"]
df_warriors
# Out:
#            id              full_name abbreviation  nickname          city  \
# 7  1610612744  Golden State Warriors          GSW  Warriors  Golden State
#
#         state  year_founded
# 7  California          1946

# %%
id_warriors=df_warriors[["id"]].values[0][0]

# %% [markdown]
# La función "League Game Finder" hará una llamada a la API

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %% [markdown]
#   La siguiente línea de código hace una http request, el cual recibe la página y recibe una response o respuesta

# %%
gamefinder=leaguegamefinder.LeagueGameFinder(team_id_nullable=id_warriors)

# %%
games=gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     12022  1610612744               GSW  Golden State Warriors  0012200004
# 1     12022  1610612744               GSW  Golden State Warriors  0012200001
# 2     22022  1610612744               GSW  Golden State Warriors  1522200074
# 3     22022  1610612744               GSW  Golden State Warriors  1522200056
# 4     22022  1610612744               GSW  Golden State Warriors  1522200035
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2022-10-02  GSW vs. WAS  W  240  104  ...   0.667  11.0  36.0  47.0   29
# 1  2022-09-30    GSW @ WAS  W  239   96  ...   0.775  10.0  52.0  62.0   18
# 2  2022-07-17  GSW vs. WAS  L  201   77  ...   0.667  12.0  33.0  45.0   15
# 3  2022-07-15  GSW vs. OKC  L  202   82  ...   0.667   4.0  31.0  35.0   14
# 4  2022-07-12  GSW vs. BOS  L  199   92  ...   0.667  16.0  22.0  38.0   14
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %% [markdown]
# Podemos crear un dataframe para los juegos de los Warriors contra los Raptors en casa y en el estadio rival

# %%
games_home=games[games["MATCHUP"]=="GSW vs. TOR"]
games_away=games[games["MATCHUP"]=="GSW @ TOR"]

# %% [markdown]
# Podemos graficar la columna PLUS MINUS para ambos dataframes

# %%
import matplotlib.pyplot as plt

fig,ax=plt.subplots()
games_away.plot(x="GAME_DATE",y="PLUS_MINUS",ax=ax)
games_home.plot(x="GAME_DATE",y="PLUS_MINUS",ax=ax)
ax.legend(["away","home"])
plt.show()

# %% [markdown]
# **GET**
#
# El método GET solicita una representación de un recurso específico. Las peticiones que usan el método GET sólo deben recuperar datos.
#
# **HEAD**
#
# El método HEAD pide una respuesta idéntica a la de una petición GET, pero sin el cuerpo de la respuesta.
#
# **POST**
#
# El método POST se utiliza para enviar una entidad a un recurso en específico, causando a menudo un cambio en el estado o efectos secundarios en el servidor.
#
# **PUT**
#
# El modo PUT reemplaza todas las representaciones actuales del recurso de destino con la carga útil de la petición.
#
# **DELETE**
#
# El método DELETE borra un recurso en específico.
#
# **CONNECT**
#
# El método CONNECT establece un túnel hacia el servidor identificado por el recurso.
#
# **OPTIONS**
#
# El método OPTIONS es utilizado para describir las opciones de comunicación para el recurso de destino.
#
# **TRACE**
#
# El método TRACE realiza una prueba de bucle de retorno de mensaje a lo largo de la ruta al recurso de destino.
#
# **PATCH**
#
# El método PATCH es utilizado para aplicar modificaciones parciales a un recurso.

# %% [markdown]
# ## Llaves API y endpoints
# Una llave API es una forma de acceder a una API. Es un único set de caracteres que la API usa para identificar y autorizarte

# %% [markdown]
# Un endpoint es simplemente una localización del servicio. Es usado para encontrar la locacalización en internet, como si fuera una dirección web.

# %% [markdown]
# En muchas APIs puede que nos cobren por cada llamada, así que debemos cuidar nuestra llave API como si fuera una contraseña

# %% [markdown]
# Ejemplo con la API de IBM Watson
#
# Instalamos la librería
# ```
# pip install ibm_watson
# ```
# Cargamos el módulo
# ```
# from ibm_watson import SpeechToTextV1
# ```
# Guardamos la información en la variable **url_s2t**, para saber que url debemos usar, debemos obtener credenciales de IBM Watson, así como la llave API
# ```
# url_s2t="https://stream.watsonplatform.net/speech-to-text/api"
# iam_apikey_s2t="EOeiZxxxDxV2xxxxxxxxxxxxxxxjYen9SKARKW-"
# ```
# Creamos un objeto Speech to Text Adapter, Los parámteros son el endpoint y la llave API.
# ```
# s2t=SpeechToTextV1(iam_apikey=iam_apikey_s2t,url=url_s2t)
# ```
#
# Usamos un archivo en formato **wav** que queramos usar
# ```
# filename="hello_this_is_python.wav"
# ```
# Usamos el método open junto rb (formato binario) nos deja utilizar el archivo en formato **wav**
#
# El método **response** manda el archivo de audio a Watson Speech al servicio de texto
# ```
# with open(filename,mode="rb") as wav:
#   response=s2t.recognize(audio=wav,content_type="audio/way")
# ```
# El parámetro audio es el objeto archivo, content_type es el formato del archivo de audio
#
# El atributo resultado contiene un diccionario Python. El valor de la llave results tiene una lista que contiene un diccionario
#
# ```
# response.result
# ```
#
# Podemos asignar a una variable **recognized_text**
# ```
# recognized_text=response.result["results"][0]["alternatives"][0]["transcript"]
# ```
#
# Obtenemos el siguiente resultado:
# ```
# recognized_test:
# "hello this is python"
# ```

# %% [markdown]
# Ahora traducimos el siguiente texto en español:
# ```
# from ibm_watson import LanguageTranslatorV3
# ```
# Asignamos el endpoint del servicio a la variable url
#
# ```
# url="https://gateway.watsonplatform.net/language-translator/api"
# apikey_it="dU2SaxxxxxxxxxxxxxxxasdfCuasdf"
# ```
# version_it es la versión de la API que vamos a usar
# ```
# version_it="2018-05-01"
# ```
# El método LanguageTranslatorV3 regresa el código del lenguaje
# ```
# language_translator=LanguageTranslatorV3(iam_apikey=apikey_it,url=url_lt,version=version_lt)
#  ```
#  Usamos la variable previamente usada
# ```
# recognized_text="hello this is python"
# ```
#
# El método **translate** es un objeto response detallado
# ```
# translation_response=language_translator.translate(text=recognized_text,model_id="en-es")
# ```
# El parámetro text es el tipo de modelo que queremos usar
#
# Usamos el método get result para obtener la traducción
#
# ```
# translation=translation_response.get_result()
# ```
#
# Resultado:
# ```
# translation
# {"translations":[{"translation":"Hola, esta es la pitón. "}]. "word_count":4,"character_count":21}
# ```
#
# Otro ejemplo:
# ```
# translation_new=language_translator.translate(text=spanish_translation,model_id="es-en").get_result()
#
# translation_eng=translation_new["translations"][0]["translation"]
# ```
# Resultado:
# ```
# translation_eng
# "Hey, this is the python
# ```
#
# Ahora con francés
# ```
# Frecnh_translation_new=language_translator.translate(text=translation_eng,model_id="en-fr").get_result()
# ```
# Resultado
# ```
# French_translation["translations"][0]["translation"]
#
# "Hé, c'est le python. "
#
# ```
